# %% [markdown]
# <a href="https://colab.research.google.com/github/MoabFarias/Mapa_de_FABRICAS_SOLAR-/blob/main/Mapa_Grupo_SOLAR_COCA_COLA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# Coordenadas das cidades (latitude, longitude)
cities = {
    "Suape-PE": (-8.3975, -34.9633),
    "Maceió-AL": (-9.6658, -35.7353),
    "Maracanaú-CE": (-3.8766, -38.6256),
    "Macaíba-RN": (-5.8522, -35.3552),
    "São Luís-MA": (-2.5391, -44.2829),
    "Simões Filho-BA": (-12.7844, -38.3906),
    "Vitória da Conquista-BA": (-14.8615, -40.8442),
    "Várzea Grande-MT": (-15.6467, -56.1325),
    "Belém-PA": (-1.4558, -48.5044),
    "Benevides-PA": (-1.3617, -48.2434),
    "Manaus-AM": (-3.1190, -60.0217),
    "Porto Velho-RO": (-8.7608, -63.9004),
}

# Criar o mapa do Google Maps com Folium
my_map = folium.Map(location=[-10.0, -55.0], zoom_start=4)

# Adicionar marcadores para as cidades
for city, (lat, lon) in cities.items():
    folium.Marker(
        location=[lat, lon],
        popup=city,  # Adiciona um pop-up com o nome da cidade
        icon=folium.Icon(color="red", icon="fa-location-arrow", prefix="fa")
    ).add_to(my_map)

# Salvar o mapa como um arquivo HTML
my_map.save("/content/drive/MyDrive/MOAB/Python Colab\Mapa Grupo SOLAR COCA COLA.html")

# Visualizar o mapa no navegador (opcional)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c26fba18be7a71c326e9d64fbdd43b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c26fba18be7a71c326e9d64fbdd43b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c26fba18be7a71c326e9d64fbdd43b2 = L.map(
#                 &quot;map_1c26fba18be7a71c326e9d64fbdd43b2&quot;,
#                 {
#                     center: [-10.0, -55.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cb2b9cf084fe0de6cfc3c2dda41f502 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3cb2b9cf084fe0de6cfc3c2dda41f502.addTo(map_1c26fba18be7a71c326e9d64fbdd43b2);
#
#
#             var marker_29f2e94690b9af2ab323a40370abcd88 = L.marker(
#                 [-8.3975, -34.9633],
#                 {}
#             ).addTo(map_1c26fba18be7a71c326e9d64fbdd43b2);
#
#
#             var icon_40faa8383c9476cba941a41e6467a1cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-location-arrow&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_29f2e94690b9af2ab323a40370abcd88.setIcon(icon_40faa8383c9476cba941a41e6467a1cc);
#
#
#         var popup_9881b253cb487f24eef35447f830f9d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51440686639fe48b4c71565481860e4f = $(`&lt;div id=&quot;html_51440686639fe48b4c71565481860e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suape-PE&lt;/div&gt;`)[0];
#                 popup_9881b253cb487f24eef35447f830f9d7.setContent(html_51440686639fe48b4c71565481860e4f);
#
#
#
#         marker_29f2e94690b9af2ab323a40370abcd88.bindPopup(popup_9881b253cb487f24eef35447f830f9d7)
#         ;
#
#
#
#
#             var marker_094f9ca2bfdb97b6a1302698a3f2613d = L.marker(
#                 [-9.6658, -35.7353],
#                 {}
#             ).addTo(map_1c26fba18be7a71c326e9d64fbdd43b2);
#
#
#             var icon_982952656aed2a145ce84fd137205d40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-location-arrow&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_094f9ca2bfdb97b6a1302698a3f2613d.setIcon(icon_982952656aed2a145ce84fd137205d40);
#
#
#         var popup_c7faf7a8015d8dc5ab8a6adbcba358d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa9d4cf66cefad35bbfad36075c1efb0 = $(`&lt;div id=&quot;html_aa9d4cf66cefad35bbfad36075c1efb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Maceió-AL&lt;/div&gt;`)[0];
#                 popup_c7faf7a8015d8dc5ab8a6adbcba358d0.setContent(html_aa9d4cf66cefad35bbfad36075c1efb0);
#
#
#
#         marker_094f9ca2bfdb97b6a1302698a3f2613d.bindPopup(popup_c7faf7a8015d8dc5ab8a6adbcba358d0)
#         ;
#
#
#
#
#             var marker_f9b73f5d21bf51112ae7ce519c2deed9 = L.marker(
#                 [-3.8766, -38.6256],
#                 {}
#             ).addTo(map_1c26fba18be7a71c326e9d64fbdd43b2);
#
#
#             var icon_a3ba6fd62a16b2cca5725d3cc6e837f9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-location-arrow&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f9b73f5d21bf51112ae7ce519c2deed9.setIcon(icon_a3ba6fd62a16b2cca5725d3cc6e837f9);
#
#
#         var popup_22330adcc16c42f06b13f0bedf745a08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16c2d51d32e26e52f7f78baa1c0ae155 = $(`&lt;div id=&quot;html_16c2d51d32e26e52f7f78baa1c0ae155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Maracanaú-CE&lt;/div&gt;`)[0];
#                 popup_22330adcc16c42f06b13f0bedf745a08.setContent(html_16c2d51d32e26e52f7f78baa1c0ae155);
#
#
#
#         marker_f9b73f5d21bf51112ae7ce519c2deed9.bindPopup(popup_22330adcc16c42f06b13f0bedf745a08)
#         ;
#
#
#
#
#             var marker_47bc8570f12c6283b676687ef34cb65e = L.marker(
#                 [-5.8522, -35.3552],
#                 {}
#             ).addTo(map_1c26fba18be7a71c326e9d64fbdd43b2);
#
#
#             var icon_6e37d2226a8a53515ac8ed839a4a5e86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-location-arrow&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &q

# %%
# prompt:  como publicar e gerar link para acesso desssa visualização

# Para publicar o mapa e gerar um link de acesso, você pode usar um serviço de hospedagem de arquivos como o GitHub Pages.

# 1. Salve o arquivo HTML do mapa:
#    - O código fornecido já salva o mapa como "mapa_brasil_cidades.html".

# 2. Crie um repositório no GitHub:
#    - Crie um novo repositório público no GitHub.

# 3. Envie o arquivo HTML para o repositório:
#    - Use o Git para enviar o arquivo "mapa_brasil_cidades.html" para o repositório do GitHub.

# 4. Configure o GitHub Pages:
#    - Nas configurações do repositório, vá em "Pages".
#    - Selecione a branch "main" (ou a branch que contém o arquivo HTML).
#    - Salve as alterações.

# 5. Obtenha o link do mapa:
#    - O GitHub Pages gerará um link para acessar o mapa. O link será algo como:
#      https://seu-nome-de-usuario.github.io/nome-do-repositorio/mapa_brasil_cidades.html

# Agora você pode compartilhar o link do mapa com outras pessoas!
# Out:
#   File "<ipython-input-48-26f54c781eb8>", line 1
#     como publicar e gerar link para acesso
#          ^
# SyntaxError: invalid syntax
